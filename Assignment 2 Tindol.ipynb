# %% [markdown]
# # CIS 2650 - Assignment 2

# %% [markdown]
# ##### Instructions:
# Read each question carefully and type the program to answer each question in the empty cell after that. Provide appropriate documentation of your code wherever possible. Submit the assignment in the IPython document file notebook (ipynb) format. You can save this .ipynb notebook after writing your code on the appropriate cells below and rename it as Assignment2_XXX.ipynb, where XXX is your last name. Upload the renamed notebook in the dropbox on e-learning.

# %% [markdown]
# ##### Question 1 (40 points):
#
# The Fast Freight Shipping Company charges the following rates:![Captddddure.PNG](attachment:Captddddure.PNG)
#
# Write a program that asks the user to enter the weight of a package (float or integer) and then displays the Shipping charges (Use if-elif decision structure to answer this question).
#
# Sample output:
#
# ![Capture.PNG](attachment:Capture.PNG)

# %%
####Question 1 Code:

num1 = eval(input("Enter the weight of the package: "))

if num1 <= 2:
    print("Shipping charge: $ 1.50")
elif num1 > 2 and num1 <= 6:
    print("Shipping charge: $ 3.00")
elif num1 > 6 and num1 <= 10:
    print("Shipping charge: $ 4.00")
else:
    print("Shipping charge: $ 4.75")
# Out:
# Enter the weight of the package: 8
# Shipping charge: $ 4.00

# %% [markdown]
# ##### Question 2 (40 points):
#
# Write a program that asks the user to enter five test scores (use an appropriate loop). The program should display a letter grade for each score and the average test score (use an appropriate loop).
# ![Capture3.1.PNG](attachment:Capture3.1.PNG)
#
# Sample Output:
#
# ![Capture1111.PNG](attachment:Capture1111.PNG)

# %%
####Question 2 Code:

list1 = []

while len(list1) != 5:
    num1 = eval(input("Enter score 1: "))
    list1.append(num1)
    
    if(num1>=90):
        num1grade = "A"
    elif(num1>=80 and num1<90):
        num1grade = "B"
    elif(num1>=70 and num1<80):
        num1grade = "C"
    elif(num1>=60 and num1<70):
        num1grade = "D"
    else:
        num1grade = "F"
    
    num2 = eval(input("Enter score 2: "))
    list1.append(num2)
    
    if(num2>=90):
        num2grade = "A"
    elif(num2>=80 and num2<90):
        num2grade = "B"
    elif(num2>=70 and num2<80):
        num2grade = "C"
    elif(num2>=60 and num2<70):
        num2grade = "D"
    else:
        num2grade = "F"
    
    num3 = eval(input("Enter score 3: "))
    list1.append(num3)
    
    if(num3>=90):
        num3grade = "A"
    elif(num3>=80 and num3<90):
        num3grade = "B"
    elif(num3>=70 and num3<80):
        num3grade = "C"
    elif(num3>=60 and num3<70):
        num3grade = "D"
    else:
        num3grade = "F"
        
    num4 = eval(input("Enter score 4: "))
    list1.append(num4)
    
    if(num4>=90):
        num4grade = "A"
    elif(num4>=80 and num4<90):
        num4grade = "B"
    elif(num4>=70 and num4<80):
        num4grade = "C"
    elif(num4>=60 and num4<70):
        num4grade = "D"
    else:
        num4grade = "F"
        
    num5 = eval(input("Enter score 5: "))
    list1.append(num5)
    
    if(num5>=90):
        num5grade = "A"
    elif(num5>=80 and num5<90):
        num5grade = "B"
    elif(num5>=70 and num5<80):
        num5grade = "C"
    elif(num5>=60 and num5<70):
        num5grade = "D"
    else:
        num5grade = "F"
    
    avg=(num1+num2+num3+num4+num5)/5
    avg = float(avg)
    
    if(avg>=90):
        avggrade = "A"
    elif(avg>=80 and avg<90):
        avggrade = "B"
    elif(avg>=70 and avg<80):
        avggrade = "C"
    elif(avg>=60 and avg<70):
        avggrade = "D"
    else:
        avggrade = "F"
    
    print("score          numeric grade          letter grade")
    print("--------------------------------------------------")
    print("score 1:" + '        ' +  str(num1) + '                  ' + str(num1grade))
    print("score 2:" + '        ' +  str(num2) + '                  ' + str(num2grade))
    print("score 3:" + '        ' +  str(num3) + '                  ' + str(num3grade))
    print("score 4:" + '        ' +  str(num4) + '                  ' + str(num4grade))
    print("score 5:" + '        ' +  str(num5) + '                  ' + str(num5grade))
    print("--------------------------------------------------")
    print("Average score: " + str(avg)+ '                    ' + str(avggrade))
# Out:
# Enter score 1: 55.5
# Enter score 2: 56.7
# Enter score 3: 80.4
# Enter score 4: 80.
# Enter score 5: 88.5
# score          numeric grade          letter grade
# --------------------------------------------------
# score 1:        55.5                  F
# score 2:        56.7                  F
# score 3:        80.4                  B
# score 4:        80.0                  B
# score 5:        88.5                  B
# --------------------------------------------------
# Average score: 72.22                    C

# %% [markdown]
# ##### Question 3 (20 points):
# The population of a country reached 1 billion people by the end of 2019, and was growing at the rate of 1.1% each year. Assuming that the population continues to grow at the same rate, approximately when will the population reach more than 8 billion?

# %%
### Question 3 code 
year = 2019
population = 1000000000
rate = .011

while population <= 8000000000 :
    population += rate * population 
    year += 1
    if population < 8000000000:
        print('Population is not yet 8 billion it is currently' + ' ' + str(int(population)) + ' ' + "in year" + ' ' + str(year))
print('Population has exceeded 8 billion by year ' + str(year))
# Out:
# Population is not yet 8 billion it is currently 1011000000 in year 2020
# Population is not yet 8 billion it is currently 1022121000 in year 2021
# Population is not yet 8 billion it is currently 1033364331 in year 2022
# Population is not yet 8 billion it is currently 1044731338 in year 2023
# Population is not yet 8 billion it is currently 1056223383 in year 2024
# Population is not yet 8 billion it is currently 1067841840 in year 2025
# Population is not yet 8 billion it is currently 1079588100 in year 2026
# Population is not yet 8 billion it is currently 1091463569 in year 2027
# Population is not yet 8 billion it is currently 1103469669 in year 2028
# Population is not yet 8 billion it is currently 1115607835 in year 2029
# Population is not yet 8 billion it is currently 1127879521 in year 2030
# Population is not yet 8 billion it is currently 1140286196 in year 2031
# Population is not yet 8 billion it is currently 1152829344 in year 2032
# ...
