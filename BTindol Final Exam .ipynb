# %% [markdown]
# # EXAM 3 CIS2650
#
# ## Due date: 12 / 14 / 2020 by 11:59 PM
#
# ## Total Points : 200
#
# ## Type your name here :
#
#
# ### Please download two excel files exam3_1.csv and exam3_2.csv for answering the questions that follow.
#
# ### Save both excel files in the working directory of Python or in the same folder as this .ipynb file
#
# ### Write your programs in the space provided in this notebook and upload it on the dropbox before the due date.

# %% [markdown]
# ## Data Description:
#
# The data contains information on sales transaction of various products across multiple stores of a retail chain.
#
# ### exam3_1.csv
#
# T_id : Transaction ID
#
# Name : Names of the sales person involved in the transaction
#
# Date : Date of the transaction
#
# Month : Month of the transaction
#
# Weekday : Date of the week when transaction took place
#
# Quarter : Quarter when the transaction took place
#
# ### exam3_2.csv
#
# T_id : Transaction ID
#
# Product : Product sold in the transaction
#
# Units : Number of units sold in the transaction
#
# Dollars : The dollar value of the transaction

# %% [markdown]
# Question 1 : Load exam3_1.csv file and exam3_2.csv file using the Pandas library functions and use the appropriate functions to print the following:
#
# a) Names of all columns in the files exam3_1 and exam3_2 (10 points)
#
# Your outcome should print the following statements
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
#dir(pd) check name of built in functions for reference

# %%
#Answer 1 (Write your code below)
import pandas as pd
df1 = pd.read_csv("exam3_1.csv");df2 = pd.read_csv("exam3_2.csv");

def output():
    df1 = pd.read_csv("exam3_1.csv")
    df2 = pd.read_csv("exam3_2.csv");
    print("The names of the columns in exam3_1 are, " + df1.columns[0] + ", "+ df1.columns[1] + ", "+ df1.columns[2] + ", "+ df1.columns[3] + ", "+ df1.columns[4] + ", "+ df1.columns[5])
    print("The names of the columns in exam3_2 are, " + df2.columns[0] +  ", "+ df2.columns[1] +  ", "+ df2.columns[2] + ", "+ df2.columns[2] + ", "+ df2.columns[3])

output()
# Out:
# The names of the columns in exam3_1 are, T_id, Name, Date, Month, Weekday, Quarter
# The names of the columns in exam3_2 are, T_id, Product, Units, Units, Dollars

# %% [markdown]
# Question 2: Load exam3_1.csv file using the Pandas library functions to answer the following question:
#
# The file exam3_1.csv has the information on sales transactions. Use the appropriate function or attributes of a pandas
# library dataframe to determine the transaction id in the row number entered by the user.  (Points : 20)
#
# Possible outcome (Note if the image is not visible select this cell and click run) :
#
# ![image.png](attachment:image.png)

# %%
#Answer 2 (Write your code below) 
exam3_1 = pd.read_csv("exam3_1.csv");exam3_2 = pd.read_csv("exam3_2.csv");

# To get correct suffix after number 
def o(numb):
    if numb < 20: #determining suffix for < 20
        if numb == 1: 
            suffix = 'st'
        elif numb == 2:
            suffix = 'nd'
        elif numb == 3:
            suffix = 'rd'
        else:
            suffix = 'th'  
    else:   #determining suffix for > 20
        tens = str(numb)
        tens = tens[-2]
        unit = str(numb)
        unit = unit[-1]
        if tens == "1":
           suffix = "th"
        else:
            if unit == "1": 
                suffix = 'st'
            elif unit == "2":
                suffix = 'nd'
            elif unit == "3":
                suffix = 'rd'
            else:
                suffix = 'th'
    return str(numb)+ suffix

def find_index():
    row = eval(input("Enter the row number in the spreadsheet for which you need transaction id: "))
    print("The transaction id for the " + o(row) + " is " + str(exam3_1.iloc[row,0]))

find_index()
# Out:
# Enter the row number in the spreadsheet for which you need transaction id: 234
# The transaction id for the 234th is 182

# %% [markdown]
# Question 3: Load 'exam3_2.csv' file using the Pandas library functions and write a program to answer the following
# questions:
#
# a) Print the number of unique products in the Product column of the spredsheet  exam3_2.     (10 points)
#
# b) Print the names of the unique products featured in the Product column of the spreadsheet exam3_2. (10 points)
#
#
# Outcome Image (Note : your code should fill the blanks below with an appropriate answer)
#
# ![image.png](attachment:image.png)

# %%
#Answer 3 (Write your code below) 
exam3_1 = pd.read_csv("exam3_1.csv");exam3_2 = pd.read_csv("exam3_2.csv");

def unique_output():
    print("The unique products in the column 'Product' of exam_2 are: " + str(len(exam3_2.Product.unique())))
    print("The unique names in the column 'Product' of exam_2 are: " + ", " + exam3_2.Product.unique()[0] + " , " + exam3_2.Product.unique()[1] + " , " + exam3_2.Product.unique()[2] + " , " + exam3_2.Product.unique()[3] + " , " + exam3_2.Product.unique()[4])

unique_output()
# Out:
# The unique products in the column 'Product' of exam_2 are: 5
# The unique names in the column 'Product' of exam_2 are: , eye liner , lipstick , mascara , lip gloss , foundation

# %% [markdown]
# Question 4: Load 'exam3_2.csv' file  using the Pandas library functions and write a program to answer
#
# the following question:
#
# a) Print the min and max values of units and dollar values for the transactions. Use the approproate function to estimate
#
# the mean and max values in the columns units and dollars. Round the max and min values to two places of decimal. (20 points)
#
# Outcome(Note : your code should fill the blanks below with an appropriate answer):
#
#
# ![image.png](attachment:image.png)

# %%
#Answer 4 (Write your code below) 
exam3_2.describe()

def answer_4():
    ams = exam3_2.describe()
    meanunit = round(ams.iloc[1,1],2)
    maxunit = round(ams.iloc[7,1],2)
    meandollar = round(ams.iloc[1,2],2)
    maxdollar = round(ams.iloc[7,2],2)
    print("The mean units sold in each transaction are: " + str(meanunit))
    print("The max units sold in any transaction are: " + str(amz2))
    print("The mean dollar value of transaction is: " + str(meandollar))
    print("The max mean dollar value of transaction is: " + str(maxdollar))
answer_4()
# Out:
# The mean units sold in each transaction are: 41.62
# The max units sold in any transaction are: 95.0
# The mean dollar value of transaction is: 126.87
# The max mean dollar value of transaction is: 287.8

# %% [markdown]
# Question 5: Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas library functions and write a program to answer
#
# the following question:
#
# a) Print the Transaction ID (T_id) of the transaction with maximumn 'Dollars' amount in exam3_2 file
#
# (10 points)
#
# Hint - First find the maximum dollar value of a transaction and then get the Transaction ID.
#
# Possible outcome (Note: your program should fill the blank below with the desired answer)
#
# ![image.png](attachment:image.png)

# %%
#Answer 5 (Write your code below) 
def get_max():
    answer = exam3_2.max(axis = 0)[0]
    print("The T_id of the transaction with maximum dollar amount is " + str(answer))
    
get_max()
# Out:
# The T_id of the transaction with maximum dollar amount is 1900

# %% [markdown]
# Question 6 :  Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas library functions and
#
# write a program to answer the following question:
#
# Pre processing : Match the columns in the exam3_1 and exam3_2 based on the 'T_id' column to create a
#
# new dataframe exam3_3. The  exam3_3 should have only those thransactions whose T_id is present in
#
# both exam3_1 and exam3_2. Answer the following questions.
#
#
# a) Print the number of transactions that are present in both exam3_1 and exam3_2   (10 points)
#
# b) Find the maximum value in column Units and maximum value in column Dollars in the merged dataframe (exam3_3). Find
#
# for how many transactions do units value is maximum units value and dollar value is the maximum dollar value (10 points)
#
# Outcome (Note: your program should fill the blank below with the desired answer)
#
# ![image.png](attachment:image.png)

# %%
#Answer 6 (Write your code below) 
def final_merged():
    merged_data = pd.merge(exam3_1,exam3_2, on = 'T_id')
    # Max unit values and max dollars values are there any missed matched values where they both are max
    maxunitvals = merged_data[merged_data.Units == merged_data.Units.max()]
    findit =merged_data.loc[merged_data['Dollars'].idxmax()][0]
    exists = findit in maxunitz.Units

    maxdoll = len(merged_data[merged_data.Dollars == merged_data.Dollars.max()])
    maxunit = len(merged_data[merged_data.Units == merged_data.Units.max()])
    lenall = maxdoll + maxunit
    
    if exists == False:
        print("Number of transactions present in both exam3_1 and exam3_2 are: " + str(len(merged_data)))
        print("Number of transactions with max units value and max dollar value are " + str(lenall))
    else:
        print("Number of transactions with max units value and max dollar value are " + str(lenall) + " but there are overlapping values.")

    
final_merged()
# Out:
# Number of transactions present in both exam3_1 and exam3_2 are: 1800
# Number of transactions with max units value and max dollar value are 16

# %% [markdown]
# Question 7 :  Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas library functions. Do
#
# the preprocessing as described.
#
# Pre processing : Match the columns in the exam3_1 and exam3_2 based on the 'T_id' column to create a
#
# new dataframe exam3_3. The exam3_3 should have only those transactions whose T_id is present in both
#
# exam3_1 and exam3_2.
#
#
# Identify the transaction that involved the maximum dollar amount in the dataframe exam3_3 and answer
#
# the follwing questions:
#
#
# a) Print the maximum sales amount (Dollars) in any transaction in the dataframe exam3_3  (10 points)
#
# b) Print the name of the salesman and the product that was involved in the transaction of the maximum
#
# dollar amount (10 points)
#
# Outcome (Note: your outcome should fill the blanks shown below with the appropriate answers)
#
# ![image.png](attachment:image.png)

# %%
#Answer 7 (Write your code below) 

def answer_7():
    exam3_3= pd.merge(exam3_1,exam3_2, on = 'T_id')
    maxdollar = exam3_3.loc[exam3_3['Dollars'].idxmax()][8]
    personinvolved = exam3_3.loc[exam3_3['Dollars'].idxmax()][1]
    productsold = exam3_3.loc[exam3_3['Dollars'].idxmax()][6]
    print("The maximum sale amount in dollars is " + str(round(maxdollar,3)))
    print("The sales person involved in this transaction is " + str(personinvolved) + " and the product sold is " + str(productsold))
answer_7()
# Out:
# The maximum sale amount in dollars is 287.797
# The sales person involved in this transaction is Hallagan and the product sold is foundation

# %% [markdown]
# Question 8 :  Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas library functions. Do
#
# the preprocessing as described.
#
# Pre processing : Match the columns in the exam3_1 and exam3_2 based on the 'T_id' column to create a
#
# new dataframe exam3_3. The exam3_3 should have only those transactions whose T_id is present in both
#
# exam3_1 and exam3_2.
#
# Using a for / while loop answer the questions below:
#
# a) Count the total number of transactions that have sale value of more than 250$. ( 10 points)
#
# b) Create a list ('name') that has the names of the products that are involved in each transaction valued more than
#
# 250$ and print it. (10 points)
#
# c) Also identify how many times the product 'foundation' appears in the above list 'name'. You can write another loop
#
# to accomplish this task. (10 points)
#
# Outcome (Note: your outcome should fill the blanks with the appropriate answers) :
#
# ![image.png](attachment:image.png)

# %%
transactioncountover250  = 0
productlistname  = []
productlistTid = []
productlistdollar = []
def foo2(productlistname):
    return [i for i in productlistname if i == "foundation" ]
timesfoundationappeared = 0
for i in range(exam3_3.shape[0]): # data.shape[0] gives number of rows 
    if exam3_3.iloc[i,8] > 250: # likes is the first column so the index is 0
        transactioncountover250 = transactioncountover250+1
    if exam3_3.iloc[i,8] > 250: 
        productlistname.append(exam3_3.iloc[i,6])
    xen = foo2(productlistname)
    xen2 = len(xen)
print("Number of transactions with more than 250$ value are: " + str(transactioncountover250))
print("The list containing the names of products sold in these transactions is: " + str(productlistname))
print("The number of times foundation appeared in the above list is: " + str(xen2))
# Out:
# Number of transactions with more than 250$ value are: 217
# ...

# %% [markdown]
# Question 9 :  Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas library functions.
#
# Match the columns in the exam3_1 and exam3_2 based on the 'T_id' column to create a new dataframe
#
# exam3_3. The  exam3_3 should have only those transactions whose T_id is present in both  exam3_1 and
#
# exam3_2.
#
#
# The Quarter column in the dataframe exam3_3 contains the quarter in which the transaction was
#
# completed. A row in the Quarter column and take any of the four values (Q1,Q2,Q3,Q4) representing
#
# each of the four quarters. Answer the following question:
#
#
# a) Print how many transactions were completed in the quarter Q1 in exam3_3 (10 points)
#
# Partial Outcome (Note: your outcome should fill the blanks with the appropriate answers)
#
# ![image.png](attachment:image.png)

# %%
#Answer 9 (Write your code below) 

def Answer_9():
    ex3 = exam3_3.groupby('Quarter').agg('nunique')
    q1tranasctions = ex3.iloc[0,0]
    print("The number of transactions completed in Q1 quarter are " + str(q1tranasctions))
    
Answer_9()
# Out:
# The number of transactions completed in Q1 quarter are 489

# %% [markdown]
# Question 10 :  Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas ans Matplotlib library  functions. Match
#
# the columns in the exam3_1 and exam3_2 based on the 'T_id' column to create a new  dataframe exam3_3. The  exam3_3
#
#
# should have only those transactions whose T_id is present in both  exam3_1 and exam3_2.
#
# Answer the following question (15 points):
#
# Make a plot using the dataframe exam3_3 which contains three subplots as shown below with
#
# a) First plot is a histogram for the column Units.
# b) Second plot is a histogram for the column Dollars.
# c) Thri plot is relates Units (x-axis) and Dollars (y-axis). Use linestyle = 'dashed', linewidth = 2, color = blue.
#
# Outcome should look like below :
#
# ![image.png](attachment:image.png)

# %%
#Answer 10 (Write your code below) 
# Import the Matplotlib
import matplotlib as mlp
# import pyplot module / collection of functions as plt
import matplotlib.pyplot as plt
# The following command allows to see plots in the Jupyter library in can you can not see them.
# %matplotlib inline

dollars = exam3_3['Dollars']
units = exam3_3['Units']

plt.subplot(3,2,1)
exam3_3['Units'].hist()
plt.title("Units", color = "red")
plt.xlabel("Units", color = "red")

plt.subplot(3,2,2)
exam3_3['Dollars'].hist()
plt.title("Dollars", color = "red")
plt.xlabel("Dollars", color = "red")

plt.subplot(3,2,3)
plt.plot(units,dollars, linewidth = 4)
plt.title("Units vs Dollars", color = "red")
plt.xlabel("Units", color = "red")
plt.ylabel("Dollars", color = "red")
# Out:
# Text(0, 0.5, 'Dollars')

# %% [markdown]
# Question 11: Load 'exam3_1.csv' file and 'exam3_2.csv' file using the Pandas ans Matplotlib library
#
# functions. Match the columns in the exam3_1 and exam3_2 based on the 'T_id' column to create a new
#
# dataframe exam3_3. The  exam3_3 should have only those transactions whose T_id is present in both
#
# exam3_1 and exam3_2.
#
#
# The Quarter column in the dataframe exam3_3 contains the quarter in which the transaction was
#
# completed. Identify the number of transactions in each quarter. This can be done by filtering the
#
# dataframe by quarter and finding the number of rows. Answer the following question:
#
#
# a) Plot a pie chart demonstrating the share of transactions in each quarter as below. (25 points)
#
# ![image.png](attachment:image.png)

# %%
#Answer 11 (Write your code below) 

ex3 = exam3_3.groupby('Quarter').agg('count')
ex3.reset_index(inplace=True)


quarter = ex3.loc[:,"Quarter"]
share = ex3.loc[:,"T_id"]
#plt.pie(share); # See what removing the semicolon does 

#plt.show()
#plt.pie(share, labels = quarter); # See what removing the semicolon does 
# Explode the largest slice and add % in the plots

#plt.show()
explode = (0, 0.1, 0, 0)

plt.pie(share, labels = quarter, explode = explode,autopct='%1.1f%%');

# %% [markdown]
# ## Upload the completed notebook on elearning dropbox before 12/14/2020 by,
#
# ## (11:59 PM)
